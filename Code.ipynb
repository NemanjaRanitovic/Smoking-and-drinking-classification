# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('database.csv')

# %%
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
df.count()
# Out:
# sex                 991346
# age                 991346
# height              991346
# weight              991346
# waistline           991346
# sight_left          991346
# sight_right         991346
# hear_left           991346
# hear_right          991346
# SBP                 991346
# DBP                 991346
# BLDS                991346
# tot_chole           991346
# HDL_chole           991346
# LDL_chole           991346
# triglyceride        991346
# hemoglobin          991346
# urine_protein       991346
# serum_creatinine    991346
# SGOT_AST            991346
# SGOT_ALT            991346
# gamma_GTP           991346
# SMK_stat_type_cd    991346
# DRK_YN              991346
# dtype: int64

# %%
df['sex'].replace('Female',0,inplace = True)

# %%
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
#import pandas as pd


# Convert all columns to string type
#df = df.astype(str)

# Replace any problematic values with NaN
#df = df.apply(pd.to_numeric, errors='coerce')

# Now, plot histograms for each column
#for col in df.columns:
  #  plt.figure(figsize=(8, 6))
  #  for class_label in df['SMK_stat_type_cd'].unique():
   #     subset = df[df['SMK_stat_type_cd'] == class_label]
  #      plt.hist(subset[col], alpha=0.5, label=f'Class {class_label}')
  #  plt.title(f'Distribution of {col} by SMK_stat_type_cd')
  #  plt.xlabel(col)
   # plt.ylabel('Frequency')
  #  plt.legend()
  #  plt.show()
# Convert all columns to string type
df = df.astype(str)

# Plot histograms for each column
for col in df.columns:
    plt.figure(figsize=(8, 6))
    for class_label in df['DRK_YN'].unique():
        subset = df[df['DRK_YN'] == class_label]
        plt.hist(subset[col], alpha=0.5, label=f'Class {class_label}', bins=20)
    plt.title(f'Distribution of {col} by DRK_YN')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()
